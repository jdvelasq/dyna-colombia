# %% [markdown]
# Ley de Bradford
# ---

# %%
from techminer2 import bibliometrix

bibliometrix.sources.bradford_law(
    directory="../../data/",
    database="documents"
).plot_.update_layout(
    width=700,
    height=700,
)
