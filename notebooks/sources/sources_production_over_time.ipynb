# %% [markdown]
# Producción de revistas a lo largo del tiempo
# ---

# %%
from techminer2 import bibliometrix

bibliometrix.sources.sources_production_over_time(
   directory="../../data/",
    topics_length=20,
    #plot="cleveland",
    database="documents",
).plot_.update_layout(
    height=600,
)
