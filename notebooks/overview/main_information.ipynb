# %% [markdown]
# Información básica
# ----

# %% [markdown]
# A continuación se presentan los principales indicadores de la revista.

# %%
from techminer2 import bibliometrix

bibliometrix.overview.main_information(directory='../../data/')
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool'}
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...
