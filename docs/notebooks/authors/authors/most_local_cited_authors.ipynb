# %% [markdown]
# Autores más citados localmente
# ===

# %%
from techminer2 import bibliometrix

bibliometrix.authors.most_local_cited_authors(
    directory="../../../data/",
    topics_length=20,
).update_layout(
    width=500,
    height=700,
)
