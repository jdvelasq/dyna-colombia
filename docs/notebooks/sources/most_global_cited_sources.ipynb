# %% [markdown]
# Revistas más citadas globalmente
# ---

# %%
from techminer2 import bibliometrix

bibliometrix.sources.most_global_cited_sources(
    directory="../../data/",
    topics_length=20,
    plot="cleveland",
    database="references",
).update_layout(
    width=700,
    height=700,
)
